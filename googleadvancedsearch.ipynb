# %%
#import statements
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
import pandas as pd
import time

# %%
#initialize webdriver
driver = webdriver.Chrome()
driver.get("https://www.google.com/advanced_search")
WebDriverWait(driver, 2)
# Out:
# <selenium.webdriver.support.wait.WebDriverWait (session="a37a8da997a94007f0a9a38922ef6dd8")>

# %%
#Google Advanced Search
search = driver.find_element(By.CLASS_NAME, 'jfk-textinput')
search.click()
query = "windows, texas"
search.send_keys(query)
button = driver.find_element(By.XPATH, '//*[@id="s1zaZb"]/div[5]/div[9]/div[2]/input[2]')
button.click()

#press more buisnesses button
moreBuisnesses = driver.find_element(By.XPATH, '//*[@id="Odp5De"]/div/div/div[2]/div[1]/div[4]/g-more-link/a/div')
moreBuisnesses.click()

# %%
#scrape companies
mydict = {"Distributor Name": [], "Phone": [], "Website Url": []}
while(True):
    WebDriverWait(driver, 2)
    searchResults = driver.find_elements(By.XPATH, '//*[@jsname="GZq3Ke"]') 
    nextButton = driver.find_element(By.XPATH, '//*[@id="pnnext"]/span[2]')
    for i in searchResults:
        WebDriverWait(i, 2)
        try:
            fs = i.find_element(By.XPATH, './div/div/div/a/div/div/div[4]')
            fullstr = fs.text
            phoneNumber = fullstr[-14:-1]
            if(fullstr[-14:-13] != "("):
                phoneNumber = "N/A"
            mydict["Phone"].append(phoneNumber)
        except:
            mydict["Phone"].append("N/A")
        try:
            companies = i.find_element(By.XPATH, './div/div/div/a/div/div/div[1]')
            mydict["Distributor Name"].append(companies.text)
        except: 
            mydict["Distributor Name"].append("N/A")
        try:
            websites = i.find_element(By.XPATH, './div/div/a[1]')
            mydict["Website Url"].append(websites.get_attribute('href'))
        except: 
            mydict["Website Url"].append("N/A")
    try:
        nextButton = i.find_element(By.XPATH, '//*[@id="pnnext"]/span[2]')
        WebDriverWait(i, 5)
        nextButton.click()
    except:
        break
columnHeaders = ["Distributor Name", "Phone", "Data Source url"]
df = pd.DataFrame(mydict).T
df
# Out:
#                                                0   \
# Distributor Name            Windows of Texas, Inc
# Phone                               (682) 201-564
# Website Url       https://www.windowsoftexas.com/
#
#                                                                  1   \
# Distributor Name                       Storm Tight Windows of Texas
# Phone                                                 (281) 426-008
# Website Url       https://www.stormtightwindowstexas.com/?utm_so...
#
#                                              2   \
# Distributor Name                  Texas Windows
# Phone                             (469) 771-304
# Website Url       https://www.texaswindows.com/
#
#                                                3   \
# Distributor Name          Custom Windows of Texas
# Phone                               (713) 864-274
# Website Url       https://www.custom-windows.net/
#
#                                                                  4   \
# Distributor Name                            Superior Window Company
# Phone                                                           N/A
# Website Url       https://superiorwindowcompany.com/?utm_source=...
#
#                                                      5   \
# Distributor Name           Performance Windows Of Texas
# Phone                                               N/A
# Website Url       http://performancewindowsoftexas.com/
#
#                                                  6   \
# Distributor Name       Texas Window Store of Austin
# Phone                                 (512) 360-061
# Website Url       https://www.texaswindowstore.com/
#
#                                                  7   \
# Distributor Name        Texas Made Windows and More
# Phone                                           N/A
# Website Url       https://www.texasmadewindows.com/
#
#                                                                  8   \
# Distributor Name                       North Texas Window Solutions
# Phone                                                 (214) 351-635
# Website Url       https://www.google.com/search?lr=&safe=images&...
#
#                                               9   ...  \
# Distributor Name                Windows of Texas  ...
# Phone                                        N/A  ...
# Website Url       http://www.windowsoftexas.com/  ...
#
#                                         30                             31  \
# Distributor Name             NT Window INC                   Texas Window
# Phone                        (800) 969-883                  (832) 641-611
# Website Url       http://www.ntwindow.com/  https://www.texas-window.com/
#
#                                                                  32  \
# Distributor Name                          NewSouth Window Solutions
# Phone                                                 (346) 222-590
# Website Url       https://newsouthwindow.com/location-houston/?u...
#
#                                                   33  \
# Distributor Name               Texas Window Services
# Phone                                  (832) 515-499
# Website Url       http://www.texaswindowservice.com/
#
#                                            34   35   36   37   38   39
# Distributor Name  Affordable Windows of Texas  N/A  N/A  N/A  N/A  N/A
# Phone                           (210) 787-602  N/A  N/A  N/A  N/A  N/A
# Website Url         https://www.awotexas.com/  N/A  N/A  N/A  N/A  N/A
#
# [3 rows x 40 columns]

# %%
fileTitle = query + ".csv"
df.to_csv(fileTitle)
